# %%
import json 
import pandas as pd
import os
import csv

# %%
f = pd.read_csv("drive/My Drive/ProcessedData.csv")

# %%
from sklearn.preprocessing import LabelEncoder
feature_cols = ['DepDelayMinutes','CRSArrTime','CRSDepTime','DepDel15','windspeedKmph_y','winddirDegree_y', 'weatherCode_y',	'precipMM_y',	'visibility_y',	'pressure_y',	'cloudcover_y',	'DewPointF_y',	'WindGustKmph_y',	'tempF_y',	'WindChillF_y',	'humidity_y', 'airport_y']
X = f[feature_cols].copy(deep=True)
y = f['ArrDel15'].copy(deep=True)
le = LabelEncoder()
X['airport_y']=le.fit_transform(X['airport_y'])

# %% [markdown]
# **OVERSAMPLING**

# %% [markdown]
# SMOTE

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X_train, y_train = oversample.fit_resample(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(max_depth = 10 , learning_rate = 0.05)
xgb.fit(X_train, y_train)

y_pred = xgb.predict(X_test.values)
y_pred_xgb = [round(value) for value in y_pred]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.97      0.95    292698
#          1.0       0.86      0.71      0.78     77589
#
#     accuracy                           0.92    370287
#    macro avg       0.89      0.84      0.86    370287
# weighted avg       0.91      0.92      0.91    370287

# %% [markdown]
# ADASYN

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
from imblearn.over_sampling import ADASYN

X_train, y_train = ADASYN(sampling_strategy = 'minority').fit_resample(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(max_depth = 10 , learning_rate = 0.05)
xgb.fit(X_train, y_train)

y_pred = xgb.predict(X_test.values)
y_pred_xgb = [round(value) for value in y_pred]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94    292698
#          1.0       0.80      0.75      0.77     77589
#
#     accuracy                           0.91    370287
#    macro avg       0.87      0.85      0.86    370287
# weighted avg       0.91      0.91      0.91    370287

# %% [markdown]
# RANDOM OVER SAMPLING

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy='minority')
X_train, y_train = oversample.fit_resample(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(max_depth = 10 , learning_rate = 0.05)
xgb.fit(X_train, y_train)

y_pred = xgb.predict(X_test.values)
y_pred_xgb = [round(value) for value in y_pred]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.92      0.93    292698
#          1.0       0.73      0.80      0.76     77589
#
#     accuracy                           0.90    370287
#    macro avg       0.84      0.86      0.85    370287
# weighted avg       0.90      0.90      0.90    370287

# %% [markdown]
# **UNDERSAMPLING**

# %% [markdown]
# RANDOM UNDER SAMPLING

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
from imblearn.under_sampling import RandomUnderSampler
undersample = RandomUnderSampler(sampling_strategy='majority')
X_train, y_train = undersample.fit_resample(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(max_depth = 10 , learning_rate = 0.05)
xgb.fit(X_train, y_train)

y_pred = xgb.predict(X_test.values)
y_pred_xgb = [round(value) for value in y_pred]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.92      0.93    292698
#          1.0       0.72      0.80      0.76     77589
#
#     accuracy                           0.89    370287
#    macro avg       0.84      0.86      0.85    370287
# weighted avg       0.90      0.89      0.90    370287

# %% [markdown]
# NEAR MISS

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
from imblearn.under_sampling import NearMiss
undersample = NearMiss(version=1, n_neighbors=3)
X_train, y_train = undersample.fit_resample(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(max_depth = 10 , learning_rate = 0.05)
xgb.fit(X_train, y_train)

y_pred = xgb.predict(X_test.values)
y_pred_xgb = [round(value) for value in y_pred]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.83      0.89    292698
#          1.0       0.56      0.82      0.67     77589
#
#     accuracy                           0.83    370287
#    macro avg       0.76      0.83      0.78    370287
# weighted avg       0.87      0.83      0.84    370287

# %%
print(9+9)
# Out:
# 18

# %% [markdown]
# TOMEKS LINKS

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
from imblearn.under_sampling import TomekLinks
undersample = TomekLinks()
X_train, y_train = undersample.fit_resample(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(max_depth = 10 , learning_rate = 0.05)
xgb.fit(X_train, y_train)

y_pred = xgb.predict(X_test.values)
y_pred_xgb = [round(value) for value in y_pred]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.97      0.95    292698
#          1.0       0.87      0.71      0.78     77589
#
#     accuracy                           0.92    370287
#    macro avg       0.90      0.84      0.87    370287
# weighted avg       0.92      0.92      0.91    370287
